# %% [markdown]
# # 03 · Conventional baselines (Duval / IEC / Rogers)
# These rule-based diagnoses are the reference the unsupervised framework is compared against, and provide the external labels for ARI/NMI.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / 'src'))
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from dga.config import load_config, set_seed
cfg = load_config(); set_seed(cfg.seed)

# %%
from dga import data as dga_data, conventional
df = dga_data.load_clean()
diag = conventional.diagnose(df)
df = df.join(diag)
df['duval'].value_counts(dropna=False)

# %% [markdown]
# ## Agreement between the three rule-based methods

# %%
pd.crosstab(df['duval'], df['iec'])

# %% [markdown]
# ## Samples inside the Duval Triangle

# %%
from dga import viz
viz.set_paper_style()
fig = viz.plot_duval_triangle(df, color=df['duval']); fig
